# %% [markdown]
# References:
#
# 1. Generative Deep Learning - David Foster
# 2. Variational Autoencoder: Intuition and Implementation - Agustinus Kristiadi
# 3. Deep Learning with Python - Francois Chollet

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Input, Model
from tensorflow.keras.layers import Dense
from tensorflow.keras import datasets

# %%
#takes a list of flattened image data and plots the image list in rows
def plotImage(x_img, cols=5):
  #pick five random indices from the sample range of the image data
  random_sample_indices = [np.random.randint(low=0, high=x_img[0].shape[0]) for i in range(5)]
  #select the five images
  random_sample_images = x_img[0][random_sample_indices, :]

  #number of rows to be plotted
  rows = len(x_img)
  #create subplot axes
  fig, ax = plt.subplots(nrows=rows, ncols=cols, squeeze=False)

  for row in range(rows):
    for i, index in enumerate(random_sample_indices):
      #the image pixels are in flattened array
      #reshape the pixel array to 28*28 dimension
      ax[row, i].imshow(x_img[row][index].reshape(28,28), cmap='gray')
      ax[row, i].grid=False
      ax[row, i].set_xticks([])
      ax[row, i].set_yticks([])

  return ax, fig

# %% [markdown]
# ## Generating Dataset

# %%
def generateTrajectory(t, b, k, units=50, samples=100):
  #assert b < 2*np.sqrt(k)
  A0 = 1
  m = 1

  xt_series = np.zeros(units*samples).reshape(samples, units)

  omega = np.sqrt(k/m - (b/(2*m))**2)
  xt_series = A0*np.exp(-b*t/(2*m))*np.cos(omega*t)

  return xt_series

# %%
def generateData(t0=0, t1=5, t0_ques=0, t1_ques=10, b0= 0.5, b1=1, k0=5, k1=10, units=50, samples=500, random=True):
  assert b1 < 2*np.sqrt(k0)

  t = np.linspace(t0, t1, units).reshape(1, units)
  #xt_series = np.zeros((samples, units))
  t_ques = np.random.uniform(low=t0_ques, high=t1_ques, size=(samples,1))
  #x_ans = np.zeros(samples)

  if random:
    b = np.random.uniform(low=b0, high=b1, size=(samples,1))
    k = np.random.uniform(low=k0, high=k1, size=(samples,1))
  else:
    b = np.linspace(b0, b1, samples).reshape(-1,1)
    k = np.linspace(k0, k1, samples).reshape(-1,1)

  #omega = np.sqrt(k - b**2/4)
  xt_series = generateTrajectory(t, b, k, units=units, samples=samples)
  #np.exp(-b*t/2)*np.cos(omega*t)
  x_ans = generateTrajectory(t_ques, b, k, units=1, samples=samples)
  #np.exp(-b*t_ques)*np.cos(omega*t_ques)

  return t, xt_series, t_ques, x_ans

# %%
samples = 100000
t_train, xt_train, t_pred, x_ans = generateData(samples=samples)

# %%
#t_pred = t_pred.reshape(-1,1)
#x_ans = x_ans.reshape(-1,1)

print(t_pred.shape)
print(x_ans.shape)
print(t_train.shape)
print(xt_train.shape)
# Out:
# (100000, 1)
# (100000, 1)
# (1, 50)
# (100000, 50)

# %% [markdown]
# #Building Model

# %% [markdown]
# ##$\beta$-Variational Autoencoder

# %%
#dfine a sampling subclass of Layer
#the Sampling layer takes two inputs: mean and log_sigma
#the layer samples random samples from mean and log_sigma assuming that the mean and log_sigma are from from a gaussian distribution
class Sampling(keras.layers.Layer):
  def __init__(self, **kwargs):
    super().__init__(**kwargs)

  def call(self, inputs):
    #unpack the inputs
    z_mean, z_log_sigma = inputs
    batch_size = tf.shape(z_mean)[0]
    #size of the latent layer
    units = tf.shape(z_mean)[1]
    #generate random samples from a gaussian distribution of mean=0 and standard deviation=1
    epsilon = tf.random.normal(shape=(batch_size, units), mean=0, stddev=1)
    #shift and scale epsilon
    return z_mean + tf.math.exp(z_log_sigma)*epsilon

# %%
#create a subclass VAE of Model
#the model takes encoder and decoder models and joins them to build beta-VAE
#the model defines a training method to train the beta-VAE model so constructed
"""Variables in the class object:

   encoder               --   encoder model to produce mean and log_var as output from the input
   decoder               --   decoder model to produce the output
   reconstruction_loss   --   total loss for the output accuracy of the decoder - sum over total outputs and average over samples
   kl_loss               --   total loss for the kl-metric - sum over output units of latent layer and average over samples
   total_loss            --   reconstruction_loss + kl_loss
   beta_rec              --   parameter to control the relative significance of reconstruction loss
   beta_kl               --   parameter to control the relative significance of kl-divergence loss
"""

class VAE(Model):
  #
  def __init__(self, encoder, decoder, beta_rec=500., beta_kl=1., target_sigma=0.1, **kwargs):
    super().__init__(**kwargs)

    self.encoder = encoder
    self.decoder = decoder
    self.encoder.trainable = True
    self.decoder.trainable = True

    self.beta_rec = beta_rec
    self.beta_kl = beta_kl
    self.target_sigma = target_sigma

    #define the losses
    #Mean stores the mean value of the argument passed to it and a name for the mean value
    self.total_loss = keras.metrics.Mean(name='total_loss')
    self.total_reconstruction_loss = keras.metrics.Mean(name='reconstruction_loss')
    self.total_kl_loss = keras.metrics.Mean(name='kl_loss')

  @property
  #return the losses to be printed during training
  def metrics(self):
    return [self.total_loss, self.total_reconstruction_loss, self.total_kl_loss]

  #feeds an output of encoder and question to the decoder and returns the outputs of encoder and decoder
  #encoder input and a question is passed as input
  def call(self, inputs):
    observation, question = inputs
    z_mean, z_log_sigma, z = self.encoder(observation)
    predictions = self.decoder([question, z])

    return z_mean, z_log_sigma, z, predictions

  #training method called when called to fit
  #the method is passed a set of observation, a question for each observation and the corresponding answers
  def train_step(self, data):
    inputs = data['time_series']
    question = data['t_question']
    outputs = data['answer']

    with tf.GradientTape() as tape:
      #feed-forward step
      #calls the call() method
      z_mean, z_log_sigma, z, predictions = self([inputs, question])

      #calculate losses for the current feed-forward step
      #outputs and predictions are one dimensional so only take mean over samples
      reconstruction_loss = self.beta_rec*tf.reduce_mean(tf.reduce_sum((outputs - predictions)**2, axis=1))
      #take sum over dimension and mean over samples
      #kl_loss = 0.5*self.beta_kl*tf.reduce_mean(tf.reduce_sum(tf.square(z_mean) + 2*tf.exp(z_log_sigma) -  2*z_log_sigma, axis=1))
      kl_loss = 0.5*self.beta_kl*tf.reduce_mean(tf.reduce_sum(tf.square(z_mean)/self.target_sigma**2 + tf.exp(2*z_log_sigma)/self.target_sigma**2 - 2*z_log_sigma + 2*tf.math.log(self.target_sigma), axis=1)-3)
      loss = reconstruction_loss + kl_loss

      #calculates gradients w.r.t. the trainable weights of the model
      gradients = tape.gradient(loss, self.trainable_weights)
      #updates the trainable weights using the gradients calculated
      #method to update the weights is passed in call to compile function of the model as optimizer parameter
      self.optimizer.apply_gradients(zip(gradients, self.trainable_weights))

      #updates the current losses
      self.total_reconstruction_loss.update_state(reconstruction_loss)
      self.total_kl_loss.update_state(kl_loss)
      self.total_loss.update_state(loss)

      #return the losses name and the corresponding values
      return {m.name: m.result() for m in self.metrics}

# %%
v = tf.Variable(np.array([[1.,2.],[2.,3.],[3.,4.]]))

# %%
tf.math.squared_difference(v**2, v)
# Out:
# <tf.Tensor: shape=(3, 2), dtype=float64, numpy=
# array([[  0.,   4.],
#        [  4.,  36.],
#        [ 36., 144.]])>

# %% [markdown]
# ##Encoder

# %% [markdown]
# The encoder takes as input time series of 50 positions of the pendulum.
#
# The encoder consists of two hidden layers of different dimensions. Next, two layers for $mean$ and $\log(variance)$. Each of the two have dimension `latent_dim`, which is the dimension the latent layer. The output of the latent layer is sampled from normal distributions using the outputs of the layers `z_mean` and `z_log_var` as means and $\log(variance)$ of the gaussian distributions.

# %%
input_size = 50
latent_dim = 3

input = Input(shape=(input_size,), name='input_layer')
encoder_l1 = Dense(70, activation='elu', name='encoder_layer1')(input)
encoder_l2 = Dense(70, activation='elu', name='encoder_layer2')(encoder_l1)
z_mean = Dense(latent_dim, name='z_mean')(encoder_l2)
z_log_sigma = Dense(latent_dim, name='z_log_var')(encoder_l2)

#generate random samples from gaussian distribution with mean = z_mean and log(sigma) = z_log_sigma
z = Sampling(name='sampling_layer')([z_mean, z_log_sigma])

encoder = Model(inputs=input, outputs=[z_mean, z_log_sigma, z], name='encoder')

# %%
#the graph of the encoder model
#each node is a layer
#the description of the layers consists of the layer name, the input and the output dimension of the layer
keras.utils.plot_model(encoder, show_shapes=True)

# %% [markdown]
# ##Decoder

# %% [markdown]
# The decoder consists of hidden layers and an output layer. The input to the decoder is the gaussian sample output of the encoder and a question through question layer. The output is the answer to the question given the representation of the observation as the output of the encoder.

# %%
question_size = 1#keras.losses.mean_squared_error(outputs, predictions))

#question to be feeded to the decoder
question = Input(shape=(1,), name='question')

# %%
output_size = 1

latent_layer = Input(shape=(latent_dim,), name='latent_layer')
decoder_input = keras.layers.Concatenate()([question, latent_layer])

decoder_l1 = Dense(70, activation='elu', name='decoder_layer1')(decoder_input)
decoder_l2 = Dense(70, activation='elu', name='decoder_layer2')(decoder_l1)
decoder_out = Dense(output_size, name='decoder_layer_out')(decoder_l2)

decoder = Model(inputs=[latent_layer, question], outputs=decoder_out, name='decoder')

# %%
keras.utils.plot_model(decoder, show_shapes=True)

# %% [markdown]
# ##Train Model
#
# Each sample in the training consists of a time series of 50 positions of pendulum, the prediction time as a question and the corresponding answer to the question, which is the position o fthe pendulum.
#
# A large sample is generated by varying the frequency and the damping parameter fo the pendulum. The parameters are randomly chosen in the specified range.

# %%
pendulum = VAE(encoder, decoder, beta_rec=500.0, beta_kl=1.0e-1, target_sigma=0.1)

# %%
pendulum.beta_rec = 800.
pendulum.beta_kl = 2
pendulum.target_var = 0.01
# Out:
# 800.0
# 2
# 800.0

# %%
epochs = 200
batch_size = 500
learning_rate = 1.0e-3

pendulum.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate))
pendulum.fit({'time_series': xt_train, 't_question': t_pred, 'answer': x_ans}, batch_size=batch_size, epochs=epochs)
# Out:
# Epoch 1/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - kl_loss: 0.4085 - reconstruction_loss: 0.7354 - total_loss: 1.1439
# Epoch 2/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3846 - reconstruction_loss: 0.1170 - total_loss: 0.5016
# Epoch 3/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3829 - reconstruction_loss: 0.1230 - total_loss: 0.5059
# Epoch 4/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3821 - reconstruction_loss: 0.1262 - total_loss: 0.5083
# Epoch 5/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3842 - reconstruction_loss: 0.1262 - total_loss: 0.5104
# Epoch 6/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3815 - reconstruction_loss: 0.1322 - total_loss: 0.5136
# Epoch 7/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3830 - reconstruction_loss: 0.1319 - total_loss: 0.5150
# Epoch 8/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3818 - reconstruction_loss: 0.1447 - total_loss: 0.5266
# Epoch 9/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3826 - reconstruction_loss: 0.1287 - total_loss: 0.5113
# Epoch 10/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3839 - reconstruction_loss: 0.1339 - total_loss: 0.5178
# Epoch 11/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3834 - reconstruction_loss: 0.1397 - total_loss: 0.5230
# Epoch 12/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3822 - reconstruction_loss: 0.1301 - total_loss: 0.5122
# Epoch 13/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3811 - reconstruction_loss: 0.1408 - total_loss: 0.5219
# Epoch 14/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3811 - reconstruction_loss: 0.1310 - total_loss: 0.5121
# Epoch 15/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3827 - reconstruction_loss: 0.1326 - total_loss: 0.5153
# Epoch 16/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3815 - reconstruction_loss: 0.1419 - total_loss: 0.5235
# Epoch 17/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3822 - reconstruction_loss: 0.1375 - total_loss: 0.5197
# Epoch 18/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3812 - reconstruction_loss: 0.1551 - total_loss: 0.5363
# Epoch 19/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3838 - reconstruction_loss: 0.1365 - total_loss: 0.5204
# Epoch 20/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3804 - reconstruction_loss: 0.1339 - total_loss: 0.5142
# Epoch 21/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3828 - reconstruction_loss: 0.1292 - total_loss: 0.5120
# Epoch 22/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3802 - reconstruction_loss: 0.1422 - total_loss: 0.5224
# Epoch 23/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3815 - reconstruction_loss: 0.1323 - total_loss: 0.5137
# Epoch 24/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3819 - reconstruction_loss: 0.1323 - total_loss: 0.5142
# Epoch 25/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3818 - reconstruction_loss: 0.1293 - total_loss: 0.5111
# Epoch 26/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3826 - reconstruction_loss: 0.1403 - total_loss: 0.5228
# Epoch 27/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3823 - reconstruction_loss: 0.1328 - total_loss: 0.5152
# Epoch 28/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3802 - reconstruction_loss: 0.1348 - total_loss: 0.5150
# Epoch 29/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3820 - reconstruction_loss: 0.1349 - total_loss: 0.5169
# Epoch 30/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3802 - reconstruction_loss: 0.1397 - total_loss: 0.5198
# Epoch 31/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3811 - reconstruction_loss: 0.1318 - total_loss: 0.5129
# Epoch 32/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3804 - reconstruction_loss: 0.1334 - total_loss: 0.5137
# Epoch 33/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3808 - reconstruction_loss: 0.1357 - total_loss: 0.5165
# Epoch 34/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3804 - reconstruction_loss: 0.1338 - total_loss: 0.5142
# Epoch 35/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3826 - reconstruction_loss: 0.1371 - total_loss: 0.5197
# Epoch 36/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3818 - reconstruction_loss: 0.1310 - total_loss: 0.5128
# Epoch 37/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3819 - reconstruction_loss: 0.1437 - total_loss: 0.5256
# Epoch 38/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3819 - reconstruction_loss: 0.1389 - total_loss: 0.5208
# Epoch 39/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3811 - reconstruction_loss: 0.1274 - total_loss: 0.5085
# Epoch 40/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3822 - reconstruction_loss: 0.1337 - total_loss: 0.5159
# Epoch 41/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3796 - reconstruction_loss: 0.1442 - total_loss: 0.5238
# Epoch 42/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3806 - reconstruction_loss: 0.1285 - total_loss: 0.5091
# Epoch 43/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3807 - reconstruction_loss: 0.1343 - total_loss: 0.5150
# Epoch 44/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3800 - reconstruction_loss: 0.1377 - total_loss: 0.5177
# Epoch 45/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3812 - reconstruction_loss: 0.1387 - total_loss: 0.5199
# Epoch 46/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3834 - reconstruction_loss: 0.1272 - total_loss: 0.5106
# Epoch 47/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3807 - reconstruction_loss: 0.1309 - total_loss: 0.5115
# Epoch 48/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3808 - reconstruction_loss: 0.1356 - total_loss: 0.5164
# Epoch 49/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3805 - reconstruction_loss: 0.1333 - total_loss: 0.5138
# Epoch 50/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3807 - reconstruction_loss: 0.1330 - total_loss: 0.5137
# Epoch 51/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3801 - reconstruction_loss: 0.1373 - total_loss: 0.5174
# Epoch 52/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3809 - reconstruction_loss: 0.1303 - total_loss: 0.5111
# Epoch 53/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3812 - reconstruction_loss: 0.1317 - total_loss: 0.5128
# Epoch 54/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3808 - reconstruction_loss: 0.1395 - total_loss: 0.5204
# Epoch 55/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3804 - reconstruction_loss: 0.1319 - total_loss: 0.5122
# Epoch 56/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3803 - reconstruction_loss: 0.1361 - total_loss: 0.5163
# Epoch 57/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3807 - reconstruction_loss: 0.1299 - total_loss: 0.5106
# Epoch 58/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3823 - reconstruction_loss: 0.1363 - total_loss: 0.5186
# Epoch 59/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3802 - reconstruction_loss: 0.1462 - total_loss: 0.5264
# Epoch 60/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3810 - reconstruction_loss: 0.1359 - total_loss: 0.5169
# Epoch 61/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3799 - reconstruction_loss: 0.1337 - total_loss: 0.5135
# Epoch 62/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3802 - reconstruction_loss: 0.1341 - total_loss: 0.5144
# Epoch 63/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3776 - reconstruction_loss: 0.1363 - total_loss: 0.5140
# Epoch 64/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3811 - reconstruction_loss: 0.1448 - total_loss: 0.5259
# Epoch 65/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3795 - reconstruction_loss: 0.1378 - total_loss: 0.5173
# Epoch 66/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3805 - reconstruction_loss: 0.1304 - total_loss: 0.5110
# Epoch 67/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3806 - reconstruction_loss: 0.1269 - total_loss: 0.5075
# Epoch 68/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3805 - reconstruction_loss: 0.1417 - total_loss: 0.5222
# Epoch 69/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3805 - reconstruction_loss: 0.1306 - total_loss: 0.5111
# Epoch 70/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3821 - reconstruction_loss: 0.1329 - total_loss: 0.5151
# Epoch 71/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3810 - reconstruction_loss: 0.1387 - total_loss: 0.5197
# Epoch 72/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3795 - reconstruction_loss: 0.1336 - total_loss: 0.5131
# Epoch 73/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3800 - reconstruction_loss: 0.1320 - total_loss: 0.5119
# Epoch 74/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3799 - reconstruction_loss: 0.1460 - total_loss: 0.5258
# Epoch 75/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3800 - reconstruction_loss: 0.1323 - total_loss: 0.5123
# Epoch 76/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3806 - reconstruction_loss: 0.1322 - total_loss: 0.5129
# Epoch 77/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3787 - reconstruction_loss: 0.1369 - total_loss: 0.5157
# Epoch 78/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3803 - reconstruction_loss: 0.1345 - total_loss: 0.5148
# Epoch 79/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3795 - reconstruction_loss: 0.1384 - total_loss: 0.5179
# Epoch 80/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3795 - reconstruction_loss: 0.1408 - total_loss: 0.5203
# Epoch 81/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3793 - reconstruction_loss: 0.1309 - total_loss: 0.5102
# Epoch 82/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3784 - reconstruction_loss: 0.1449 - total_loss: 0.5233
# Epoch 83/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3793 - reconstruction_loss: 0.1368 - total_loss: 0.5162
# Epoch 84/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3796 - reconstruction_loss: 0.1307 - total_loss: 0.5103
# Epoch 85/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3795 - reconstruction_loss: 0.1328 - total_loss: 0.5123
# Epoch 86/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3793 - reconstruction_loss: 0.1314 - total_loss: 0.5107
# Epoch 87/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3796 - reconstruction_loss: 0.1300 - total_loss: 0.5095
# Epoch 88/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3790 - reconstruction_loss: 0.1328 - total_loss: 0.5118
# Epoch 89/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3795 - reconstruction_loss: 0.1306 - total_loss: 0.5100
# Epoch 90/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3809 - reconstruction_loss: 0.1333 - total_loss: 0.5142
# Epoch 91/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3794 - reconstruction_loss: 0.1379 - total_loss: 0.5172
# Epoch 92/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3798 - reconstruction_loss: 0.1517 - total_loss: 0.5315
# Epoch 93/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3789 - reconstruction_loss: 0.1361 - total_loss: 0.5150
# Epoch 94/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3787 - reconstruction_loss: 0.1334 - total_loss: 0.5120
# Epoch 95/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3787 - reconstruction_loss: 0.1325 - total_loss: 0.5111
# Epoch 96/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3795 - reconstruction_loss: 0.1301 - total_loss: 0.5096
# Epoch 97/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3803 - reconstruction_loss: 0.1325 - total_loss: 0.5127
# Epoch 98/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3796 - reconstruction_loss: 0.1368 - total_loss: 0.5164
# Epoch 99/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3792 - reconstruction_loss: 0.1385 - total_loss: 0.5177
# Epoch 100/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3794 - reconstruction_loss: 0.1305 - total_loss: 0.5099
# Epoch 101/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3801 - reconstruction_loss: 0.1347 - total_loss: 0.5148
# Epoch 102/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3783 - reconstruction_loss: 0.1280 - total_loss: 0.5063
# Epoch 103/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3802 - reconstruction_loss: 0.1368 - total_loss: 0.5170
# Epoch 104/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3786 - reconstruction_loss: 0.1494 - total_loss: 0.5279
# Epoch 105/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3787 - reconstruction_loss: 0.1322 - total_loss: 0.5110
# Epoch 106/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3790 - reconstruction_loss: 0.1313 - total_loss: 0.5104
# Epoch 107/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3781 - reconstruction_loss: 0.1351 - total_loss: 0.5132
# Epoch 108/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3788 - reconstruction_loss: 0.1465 - total_loss: 0.5253
# Epoch 109/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3784 - reconstruction_loss: 0.1335 - total_loss: 0.5118
# Epoch 110/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3789 - reconstruction_loss: 0.1356 - total_loss: 0.5145
# Epoch 111/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3783 - reconstruction_loss: 0.1383 - total_loss: 0.5166
# Epoch 112/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3804 - reconstruction_loss: 0.1353 - total_loss: 0.5157
# Epoch 113/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3782 - reconstruction_loss: 0.1381 - total_loss: 0.5164
# Epoch 114/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3784 - reconstruction_loss: 0.1286 - total_loss: 0.5070
# Epoch 115/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3786 - reconstruction_loss: 0.1274 - total_loss: 0.5060
# Epoch 116/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3790 - reconstruction_loss: 0.1324 - total_loss: 0.5114
# Epoch 117/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3791 - reconstruction_loss: 0.1428 - total_loss: 0.5219
# Epoch 118/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3787 - reconstruction_loss: 0.1407 - total_loss: 0.5194
# Epoch 119/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3789 - reconstruction_loss: 0.1337 - total_loss: 0.5126
# Epoch 120/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3798 - reconstruction_loss: 0.1275 - total_loss: 0.5073
# Epoch 121/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3770 - reconstruction_loss: 0.1333 - total_loss: 0.5103
# Epoch 122/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3781 - reconstruction_loss: 0.1392 - total_loss: 0.5174
# Epoch 123/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3802 - reconstruction_loss: 0.1400 - total_loss: 0.5202
# Epoch 124/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3800 - reconstruction_loss: 0.1271 - total_loss: 0.5070
# Epoch 125/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3797 - reconstruction_loss: 0.1423 - total_loss: 0.5220
# Epoch 126/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3781 - reconstruction_loss: 0.1421 - total_loss: 0.5202
# Epoch 127/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3783 - reconstruction_loss: 0.1322 - total_loss: 0.5105
# Epoch 128/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3781 - reconstruction_loss: 0.1305 - total_loss: 0.5086
# Epoch 129/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3804 - reconstruction_loss: 0.1395 - total_loss: 0.5199
# Epoch 130/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3793 - reconstruction_loss: 0.1349 - total_loss: 0.5142
# Epoch 131/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3798 - reconstruction_loss: 0.1453 - total_loss: 0.5251
# Epoch 132/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3786 - reconstruction_loss: 0.1329 - total_loss: 0.5115
# Epoch 133/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3802 - reconstruction_loss: 0.1315 - total_loss: 0.5117
# Epoch 134/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3790 - reconstruction_loss: 0.1325 - total_loss: 0.5116
# Epoch 135/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3772 - reconstruction_loss: 0.1314 - total_loss: 0.5087
# Epoch 136/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3774 - reconstruction_loss: 0.1339 - total_loss: 0.5113
# Epoch 137/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3788 - reconstruction_loss: 0.1368 - total_loss: 0.5156
# Epoch 138/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3784 - reconstruction_loss: 0.1381 - total_loss: 0.5165
# Epoch 139/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3799 - reconstruction_loss: 0.1271 - total_loss: 0.5071
# Epoch 140/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3779 - reconstruction_loss: 0.1435 - total_loss: 0.5214
# Epoch 141/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3784 - reconstruction_loss: 0.1360 - total_loss: 0.5144
# Epoch 142/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3800 - reconstruction_loss: 0.1311 - total_loss: 0.5111
# Epoch 143/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3782 - reconstruction_loss: 0.1370 - total_loss: 0.5152
# Epoch 144/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3781 - reconstruction_loss: 0.1358 - total_loss: 0.5139
# Epoch 145/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3783 - reconstruction_loss: 0.1366 - total_loss: 0.5148
# Epoch 146/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3794 - reconstruction_loss: 0.1449 - total_loss: 0.5243
# Epoch 147/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3799 - reconstruction_loss: 0.1278 - total_loss: 0.5078
# Epoch 148/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3777 - reconstruction_loss: 0.1397 - total_loss: 0.5173
# Epoch 149/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3781 - reconstruction_loss: 0.1357 - total_loss: 0.5138
# Epoch 150/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3774 - reconstruction_loss: 0.1278 - total_loss: 0.5052
# Epoch 151/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3770 - reconstruction_loss: 0.1264 - total_loss: 0.5034
# Epoch 152/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3775 - reconstruction_loss: 0.1365 - total_loss: 0.5140
# Epoch 153/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3791 - reconstruction_loss: 0.1354 - total_loss: 0.5145
# Epoch 154/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3779 - reconstruction_loss: 0.1397 - total_loss: 0.5176
# Epoch 155/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3782 - reconstruction_loss: 0.1288 - total_loss: 0.5070
# Epoch 156/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3782 - reconstruction_loss: 0.1312 - total_loss: 0.5094
# Epoch 157/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3780 - reconstruction_loss: 0.1447 - total_loss: 0.5228
# Epoch 158/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3790 - reconstruction_loss: 0.1327 - total_loss: 0.5118
# Epoch 159/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3768 - reconstruction_loss: 0.1330 - total_loss: 0.5098
# Epoch 160/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3784 - reconstruction_loss: 0.1354 - total_loss: 0.5138
# Epoch 161/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3781 - reconstruction_loss: 0.1390 - total_loss: 0.5171
# Epoch 162/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3779 - reconstruction_loss: 0.1299 - total_loss: 0.5077
# Epoch 163/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3791 - reconstruction_loss: 0.1418 - total_loss: 0.5210
# Epoch 164/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3786 - reconstruction_loss: 0.1312 - total_loss: 0.5098
# Epoch 165/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3786 - reconstruction_loss: 0.1298 - total_loss: 0.5084
# Epoch 166/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3796 - reconstruction_loss: 0.1357 - total_loss: 0.5153
# Epoch 167/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3782 - reconstruction_loss: 0.1359 - total_loss: 0.5141
# Epoch 168/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3781 - reconstruction_loss: 0.1388 - total_loss: 0.5170
# Epoch 169/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3779 - reconstruction_loss: 0.1337 - total_loss: 0.5116
# Epoch 170/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3772 - reconstruction_loss: 0.1337 - total_loss: 0.5109
# Epoch 171/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3784 - reconstruction_loss: 0.1272 - total_loss: 0.5056
# Epoch 172/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3777 - reconstruction_loss: 0.1279 - total_loss: 0.5056
# Epoch 173/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3780 - reconstruction_loss: 0.1430 - total_loss: 0.5210
# Epoch 174/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3794 - reconstruction_loss: 0.1308 - total_loss: 0.5103
# Epoch 175/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3774 - reconstruction_loss: 0.1392 - total_loss: 0.5166
# Epoch 176/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3780 - reconstruction_loss: 0.1370 - total_loss: 0.5150
# Epoch 177/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3761 - reconstruction_loss: 0.1339 - total_loss: 0.5100
# Epoch 178/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3763 - reconstruction_loss: 0.1373 - total_loss: 0.5136
# Epoch 179/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3783 - reconstruction_loss: 0.1288 - total_loss: 0.5071
# Epoch 180/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3789 - reconstruction_loss: 0.1390 - total_loss: 0.5179
# Epoch 181/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3771 - reconstruction_loss: 0.1282 - total_loss: 0.5052
# Epoch 182/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3784 - reconstruction_loss: 0.1363 - total_loss: 0.5147
# Epoch 183/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3765 - reconstruction_loss: 0.1454 - total_loss: 0.5219
# Epoch 184/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3756 - reconstruction_loss: 0.1426 - total_loss: 0.5181
# Epoch 185/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3785 - reconstruction_loss: 0.1357 - total_loss: 0.5143
# Epoch 186/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3771 - reconstruction_loss: 0.1248 - total_loss: 0.5019
# Epoch 187/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3784 - reconstruction_loss: 0.1301 - total_loss: 0.5086
# Epoch 188/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3765 - reconstruction_loss: 0.1359 - total_loss: 0.5124
# Epoch 189/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3784 - reconstruction_loss: 0.1311 - total_loss: 0.5095
# Epoch 190/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3783 - reconstruction_loss: 0.1379 - total_loss: 0.5162
# Epoch 191/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3780 - reconstruction_loss: 0.1326 - total_loss: 0.5105
# Epoch 192/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3776 - reconstruction_loss: 0.1358 - total_loss: 0.5134
# Epoch 193/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3772 - reconstruction_loss: 0.1345 - total_loss: 0.5116
# Epoch 194/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3797 - reconstruction_loss: 0.1396 - total_loss: 0.5193
# Epoch 195/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3766 - reconstruction_loss: 0.1303 - total_loss: 0.5069
# Epoch 196/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3765 - reconstruction_loss: 0.1316 - total_loss: 0.5081
# Epoch 197/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3785 - reconstruction_loss: 0.1385 - total_loss: 0.5171
# Epoch 198/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3773 - reconstruction_loss: 0.1350 - total_loss: 0.5124
# Epoch 199/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3784 - reconstruction_loss: 0.1296 - total_loss: 0.5079
# Epoch 200/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - kl_loss: 0.3782 - reconstruction_loss: 0.1256 - total_loss: 0.5038

# %%
input_external = np.load("/content/sample_data/inputs.npy")
output_external = np.load("/content/sample_data/outputs.npy").reshape(-1,1)

# %%
ques_external = input_external[:,-1].reshape(-1,1)
input_external = input_external[:,:-1]

# %%
epochs = 100
batch_size = 500
learning_rate = 1.0e-3

pendulum.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate))
pendulum.fit({'time_series': input_external, 't_question': ques_external, 'answer': output_external}, batch_size=batch_size, epochs=epochs)
# Out:
# Epoch 1/100
# 200/200 [==============================] - 2s 5ms/step - total_loss: 0.0420 - reconstruction_loss: 0.0969 - kl_loss: -0.0549
# Epoch 2/100
# 200/200 [==============================] - 1s 5ms/step - total_loss: -0.4272 - reconstruction_loss: 0.0682 - kl_loss: -0.4954
# Epoch 3/100
# 200/200 [==============================] - 1s 5ms/step - total_loss: -0.4308 - reconstruction_loss: 0.0662 - kl_loss: -0.4971
# Epoch 4/100
# 200/200 [==============================] - 1s 5ms/step - total_loss: -0.4350 - reconstruction_loss: 0.0632 - kl_loss: -0.4982
# Epoch 5/100
# 200/200 [==============================] - 1s 5ms/step - total_loss: -0.4404 - reconstruction_loss: 0.0585 - kl_loss: -0.4989
# Epoch 6/100
# 200/200 [==============================] - 1s 5ms/step - total_loss: -0.4477 - reconstruction_loss: 0.0516 - kl_loss: -0.4992
# Epoch 7/100
# 200/200 [==============================] - 2s 9ms/step - total_loss: -0.4561 - reconstruction_loss: 0.0434 - kl_loss: -0.4995
# Epoch 8/100
# 200/200 [==============================] - 3s 13ms/step - total_loss: -0.4641 - reconstruction_loss: 0.0355 - kl_loss: -0.4996
# Epoch 9/100
# 200/200 [==============================] - 1s 5ms/step - total_loss: -0.4700 - reconstruction_loss: 0.0297 - kl_loss: -0.4997
# Epoch 10/100
# 200/200 [==============================] - 1s 5ms/step - total_loss: -0.4731 - reconstruction_loss: 0.0266 - kl_loss: -0.4998
# Epoch 11/100
# 200/200 [==============================] - 1s 5ms/step - total_loss: -0.4754 - reconstruction_loss: 0.0244 - kl_loss: -0.4998
# Epoch 12/100
# 200/200 [==============================] - 1s 6ms/step - total_loss: -0.4778 - reconstruction_loss: 0.0220 - kl_loss: -0.4999
# Epoch 13/100
# 200/200 [==============================] - 1s 5ms/step - total_loss: -0.4806 - reconstruction_loss: 0.0193 - kl_loss: -0.4999
# Epoch 14/100
# 200/200 [==============================] - 1s 5ms/step - total_loss: -0.4827 - reconstruction_loss: 0.0172 - kl_loss: -0.4999
# Epoch 15/100
# 200/200 [==============================] - 1s 5ms/step - total_loss: -0.4837 - reconstruction_loss: 0.0161 - kl_loss: -0.4999
# Epoch 16/100
# 200/200 [==============================] - 2s 8ms/step - total_loss: -0.4841 - reconstruction_loss: 0.0157 - kl_loss: -0.4999
# Epoch 17/100
# 200/200 [==============================] - 2s 12ms/step - total_loss: -0.4844 - reconstruction_loss: 0.0154 - kl_loss: -0.4998
# Epoch 18/100
# 200/200 [==============================] - 2s 9ms/step - total_loss: -0.4846 - reconstruction_loss: 0.0152 - kl_loss: -0.4999
# Epoch 19/100
# 200/200 [==============================] - 1s 6ms/step - total_loss: -0.4847 - reconstruction_loss: 0.0150 - kl_loss: -0.4998
# Epoch 20/100
# 200/200 [==============================] - 1s 5ms/step - total_loss: -0.4849 - reconstruction_loss: 0.0149 - kl_loss: -0.4998
# Epoch 21/100
# 200/200 [==============================] - 1s 6ms/step - total_loss: -0.4850 - reconstruction_loss: 0.0148 - kl_loss: -0.4997
# Epoch 22/100
# 200/200 [==============================] - 1s 5ms/step - total_loss: -0.4851 - reconstruction_loss: 0.0148 - kl_loss: -0.4999
# Epoch 23/100
# 200/200 [==============================] - 1s 5ms/step - total_loss: -0.4852 - reconstruction_loss: 0.0145 - kl_loss: -0.4998
# Epoch 24/100
# 200/200 [==============================] - 1s 5ms/step - total_loss: -0.4851 - reconstruction_loss: 0.0146 - kl_loss: -0.4997
# Epoch 25/100
# 200/200 [==============================] - 1s 6ms/step - total_loss: -0.4853 - reconstruction_loss: 0.0145 - kl_loss: -0.4998
# Epoch 26/100
# 200/200 [==============================] - 1s 5ms/step - total_loss: -0.4851 - reconstruction_loss: 0.0146 - kl_loss: -0.4997
# Epoch 27/100
# 200/200 [==============================] - 1s 5ms/step - total_loss: -0.4851 - reconstruction_loss: 0.0146 - kl_loss: -0.4997
# Epoch 28/100
# 200/200 [==============================] - 2s 9ms/step - total_loss: -0.4852 - reconstruction_loss: 0.0145 - kl_loss: -0.4997
# Epoch 29/100
# 200/200 [==============================] - 2s 9ms/step - total_loss: -0.4854 - reconstruction_loss: 0.0144 - kl_loss: -0.4997
# Epoch 30/100
# 200/200 [==============================] - 1s 6ms/step - total_loss: -0.4854 - reconstruction_loss: 0.0143 - kl_loss: -0.4997
# Epoch 31/100
# 200/200 [==============================] - 1s 5ms/step - total_loss: -0.4853 - reconstruction_loss: 0.0144 - kl_loss: -0.4997
# Epoch 32/100
# 200/200 [==============================] - 1s 5ms/step - total_loss: -0.4852 - reconstruction_loss: 0.0146 - kl_loss: -0.4998
# Epoch 33/100
# 200/200 [==============================] - 1s 5ms/step - total_loss: -0.4853 - reconstruction_loss: 0.0143 - kl_loss: -0.4997
# Epoch 34/100
# 200/200 [==============================] - 1s 5ms/step - total_loss: -0.4853 - reconstruction_loss: 0.0144 - kl_loss: -0.4997
# Epoch 35/100
# 200/200 [==============================] - 1s 5ms/step - total_loss: -0.4854 - reconstruction_loss: 0.0143 - kl_loss: -0.4997
# Epoch 36/100
# 200/200 [==============================] - 1s 5ms/step - total_loss: -0.4855 - reconstruction_loss: 0.0142 - kl_loss: -0.4997
# Epoch 37/100
# 200/200 [==============================] - 1s 5ms/step - total_loss: -0.4853 - reconstruction_loss: 0.0143 - kl_loss: -0.4996
# Epoch 38/100
# 200/200 [==============================] - 1s 5ms/step - total_loss: -0.4857 - reconstruction_loss: 0.0142 - kl_loss: -0.4998
# Epoch 39/100
# 200/200 [==============================] - 2s 8ms/step - total_loss: -0.4855 - reconstruction_loss: 0.0143 - kl_loss: -0.4998
# Epoch 40/100
# 200/200 [==============================] - 2s 10ms/step - total_loss: -0.4855 - reconstruction_loss: 0.0142 - kl_loss: -0.4997
# Epoch 41/100
# 200/200 [==============================] - 2s 10ms/step - total_loss: -0.4855 - reconstruction_loss: 0.0142 - kl_loss: -0.4998
# Epoch 42/100
# 200/200 [==============================] - 2s 9ms/step - total_loss: -0.4855 - reconstruction_loss: 0.0141 - kl_loss: -0.4996
# Epoch 43/100
# 200/200 [==============================] - 1s 5ms/step - total_loss: -0.4856 - reconstruction_loss: 0.0142 - kl_loss: -0.4998
# Epoch 44/100
# 200/200 [==============================] - 1s 6ms/step - total_loss: -0.4856 - reconstruction_loss: 0.0142 - kl_loss: -0.4998
# Epoch 45/100
# 200/200 [==============================] - 1s 5ms/step - total_loss: -0.4857 - reconstruction_loss: 0.0141 - kl_loss: -0.4998
# Epoch 46/100
# 200/200 [==============================] - 1s 5ms/step - total_loss: -0.4857 - reconstruction_loss: 0.0141 - kl_loss: -0.4998
# Epoch 47/100
# 200/200 [==============================] - 1s 6ms/step - total_loss: -0.4857 - reconstruction_loss: 0.0141 - kl_loss: -0.4998
# Epoch 48/100
# 200/200 [==============================] - 1s 5ms/step - total_loss: -0.4857 - reconstruction_loss: 0.0141 - kl_loss: -0.4998
# Epoch 49/100
# 200/200 [==============================] - 1s 5ms/step - total_loss: -0.4858 - reconstruction_loss: 0.0140 - kl_loss: -0.4998
# Epoch 50/100
# 200/200 [==============================] - 1s 6ms/step - total_loss: -0.4856 - reconstruction_loss: 0.0142 - kl_loss: -0.4998
# Epoch 51/100
# 200/200 [==============================] - 2s 9ms/step - total_loss: -0.4856 - reconstruction_loss: 0.0142 - kl_loss: -0.4998
# Epoch 52/100
# 200/200 [==============================] - 2s 8ms/step - total_loss: -0.4857 - reconstruction_loss: 0.0141 - kl_loss: -0.4998
# Epoch 53/100
# 200/200 [==============================] - 1s 5ms/step - total_loss: -0.4859 - reconstruction_loss: 0.0140 - kl_loss: -0.4999
# Epoch 54/100
# 200/200 [==============================] - 1s 5ms/step - total_loss: -0.4857 - reconstruction_loss: 0.0140 - kl_loss: -0.4998
# Epoch 55/100
# 200/200 [==============================] - 1s 5ms/step - total_loss: -0.4857 - reconstruction_loss: 0.0141 - kl_loss: -0.4998
# Epoch 56/100
# 200/200 [==============================] - 1s 6ms/step - total_loss: -0.4857 - reconstruction_loss: 0.0141 - kl_loss: -0.4999
# Epoch 57/100
# 200/200 [==============================] - 1s 5ms/step - total_loss: -0.4857 - reconstruction_loss: 0.0141 - kl_loss: -0.4998
# Epoch 58/100
# 200/200 [==============================] - 1s 6ms/step - total_loss: -0.4858 - reconstruction_loss: 0.0140 - kl_loss: -0.4998
# Epoch 59/100
# 200/200 [==============================] - 1s 5ms/step - total_loss: -0.4859 - reconstruction_loss: 0.0139 - kl_loss: -0.4999
# Epoch 60/100
# 200/200 [==============================] - 1s 6ms/step - total_loss: -0.4857 - reconstruction_loss: 0.0141 - kl_loss: -0.4998
# Epoch 61/100
# 200/200 [==============================] - 1s 7ms/step - total_loss: -0.4859 - reconstruction_loss: 0.0139 - kl_loss: -0.4998
# Epoch 62/100
# 200/200 [==============================] - 2s 9ms/step - total_loss: -0.4857 - reconstruction_loss: 0.0141 - kl_loss: -0.4999
# Epoch 63/100
# 200/200 [==============================] - 1s 7ms/step - total_loss: -0.4858 - reconstruction_loss: 0.0141 - kl_loss: -0.4998
# Epoch 64/100
# 200/200 [==============================] - 1s 6ms/step - total_loss: -0.4859 - reconstruction_loss: 0.0139 - kl_loss: -0.4999
# Epoch 65/100
# 200/200 [==============================] - 1s 6ms/step - total_loss: -0.4859 - reconstruction_loss: 0.0139 - kl_loss: -0.4999
# Epoch 66/100
# 200/200 [==============================] - 1s 6ms/step - total_loss: -0.4859 - reconstruction_loss: 0.0140 - kl_loss: -0.4998
# Epoch 67/100
# 200/200 [==============================] - 1s 5ms/step - total_loss: -0.4859 - reconstruction_loss: 0.0140 - kl_loss: -0.4999
# Epoch 68/100
# 200/200 [==============================] - 1s 6ms/step - total_loss: -0.4859 - reconstruction_loss: 0.0140 - kl_loss: -0.4999
# Epoch 69/100
# 200/200 [==============================] - 1s 5ms/step - total_loss: -0.4860 - reconstruction_loss: 0.0139 - kl_loss: -0.4999
# Epoch 70/100
# 200/200 [==============================] - 1s 5ms/step - total_loss: -0.4858 - reconstruction_loss: 0.0141 - kl_loss: -0.4999
# Epoch 71/100
# 200/200 [==============================] - 1s 6ms/step - total_loss: -0.4859 - reconstruction_loss: 0.0139 - kl_loss: -0.4999
# Epoch 72/100
# 200/200 [==============================] - 2s 11ms/step - total_loss: -0.4859 - reconstruction_loss: 0.0139 - kl_loss: -0.4999
# Epoch 73/100
# 200/200 [==============================] - 2s 9ms/step - total_loss: -0.4860 - reconstruction_loss: 0.0139 - kl_loss: -0.4999
# Epoch 74/100
# 200/200 [==============================] - 1s 6ms/step - total_loss: -0.4860 - reconstruction_loss: 0.0138 - kl_loss: -0.4999
# Epoch 75/100
# 200/200 [==============================] - 1s 6ms/step - total_loss: -0.4860 - reconstruction_loss: 0.0140 - kl_loss: -0.4999
# Epoch 76/100
# 200/200 [==============================] - 1s 6ms/step - total_loss: -0.4860 - reconstruction_loss: 0.0139 - kl_loss: -0.4999
# Epoch 77/100
# 200/200 [==============================] - 1s 6ms/step - total_loss: -0.4859 - reconstruction_loss: 0.0140 - kl_loss: -0.4999
# Epoch 78/100
# 200/200 [==============================] - 2s 11ms/step - total_loss: -0.4860 - reconstruction_loss: 0.0138 - kl_loss: -0.4998
# Epoch 79/100
# 200/200 [==============================] - 2s 11ms/step - total_loss: -0.4861 - reconstruction_loss: 0.0139 - kl_loss: -0.4999
# Epoch 80/100
# 200/200 [==============================] - 3s 12ms/step - total_loss: -0.4860 - reconstruction_loss: 0.0139 - kl_loss: -0.4999
# Epoch 81/100
# 200/200 [==============================] - 3s 17ms/step - total_loss: -0.4859 - reconstruction_loss: 0.0140 - kl_loss: -0.4999
# Epoch 82/100
# 200/200 [==============================] - 1s 6ms/step - total_loss: -0.4861 - reconstruction_loss: 0.0138 - kl_loss: -0.4999
# Epoch 83/100
# 200/200 [==============================] - 1s 6ms/step - total_loss: -0.4861 - reconstruction_loss: 0.0138 - kl_loss: -0.4999
# Epoch 84/100
# 200/200 [==============================] - 1s 7ms/step - total_loss: -0.4860 - reconstruction_loss: 0.0139 - kl_loss: -0.4999
# Epoch 85/100
# 200/200 [==============================] - 1s 6ms/step - total_loss: -0.4862 - reconstruction_loss: 0.0137 - kl_loss: -0.4999
# Epoch 86/100
# 200/200 [==============================] - 1s 5ms/step - total_loss: -0.4861 - reconstruction_loss: 0.0138 - kl_loss: -0.4999
# Epoch 87/100
# 200/200 [==============================] - 1s 5ms/step - total_loss: -0.4861 - reconstruction_loss: 0.0138 - kl_loss: -0.4999
# Epoch 88/100
# 200/200 [==============================] - 1s 5ms/step - total_loss: -0.4861 - reconstruction_loss: 0.0138 - kl_loss: -0.4999
# Epoch 89/100
# 200/200 [==============================] - 1s 6ms/step - total_loss: -0.4862 - reconstruction_loss: 0.0138 - kl_loss: -0.4999
# Epoch 90/100
# 200/200 [==============================] - 2s 9ms/step - total_loss: -0.4861 - reconstruction_loss: 0.0138 - kl_loss: -0.4999
# Epoch 91/100
# 200/200 [==============================] - 2s 9ms/step - total_loss: -0.4861 - reconstruction_loss: 0.0138 - kl_loss: -0.4999
# Epoch 92/100
# 200/200 [==============================] - 1s 6ms/step - total_loss: -0.4862 - reconstruction_loss: 0.0137 - kl_loss: -0.4999
# Epoch 93/100
# 200/200 [==============================] - 1s 6ms/step - total_loss: -0.4862 - reconstruction_loss: 0.0137 - kl_loss: -0.4999
# Epoch 94/100
# 200/200 [==============================] - 1s 6ms/step - total_loss: -0.4861 - reconstruction_loss: 0.0138 - kl_loss: -0.4999
# Epoch 95/100
# 200/200 [==============================] - 1s 6ms/step - total_loss: -0.4861 - reconstruction_loss: 0.0138 - kl_loss: -0.4999
# Epoch 96/100
# 200/200 [==============================] - 1s 6ms/step - total_loss: -0.4862 - reconstruction_loss: 0.0137 - kl_loss: -0.4999
# Epoch 97/100
# 200/200 [==============================] - 1s 6ms/step - total_loss: -0.4861 - reconstruction_loss: 0.0138 - kl_loss: -0.4999
# Epoch 98/100
# 200/200 [==============================] - 1s 6ms/step - total_loss: -0.4862 - reconstruction_loss: 0.0138 - kl_loss: -0.4999
# Epoch 99/100
# 200/200 [==============================] - 1s 5ms/step - total_loss: -0.4862 - reconstruction_loss: 0.0137 - kl_loss: -0.4999
# Epoch 100/100
# 200/200 [==============================] - 1s 6ms/step - total_loss: -0.4862 - reconstruction_loss: 0.0137 - kl_loss: -0.4999

# %% [markdown]
# ##Validating the model
#
# The test sample is similarly generated. The answer to the question is predicted by the model for each sample.

# %%
test_samples = 10000
t_test, xt_test, t_test_pred, x_test_ans = generateData(samples=samples)

# %%
z_mu, z_logvar, z, x_test_prediction = pendulum.predict([xt_test, t_test_pred])
# Out:
# 31250/31250 [==============================] - 63s 2ms/step

# %%
z.mean(axis=0)
# Out:
# array([-0.00120292, -0.00144639,  0.00434577], dtype=float32)

# %%
x_test_ans = x_test_ans.reshape(-1,1)

# %%
def MSE(x_pred, x_ans, batch_size=10):
  mse = 0
  start = 0
  end = batch_size
  num_batches = int(x_pred.shape[0]/batch_size)

  for batch in range(num_batches):
    mse = (np.square(x_pred[start:end] - x_ans[start:end])).sum()
    start += batch_size
    end += batch_size

  return mse.mean()

# %%
mse = MSE(x_test_prediction, x_test_ans, batch_size=1000)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-b84ee64ce38f> in <cell line: 1>()
# ----> 1 mse = MSE(x_test_prediction, x_test_ans, batch_size=1000)
#
# <ipython-input-50-e9e5d877b9aa> in MSE(x_pred, x_ans, batch_size)
#       6
#       7   for batch in range(num_batches):
# ----> 8     mse = (np.square(x_pred[start:end] - x_ans[start:end])).sum()
#       9     start += batch_size
#      10     end += batch_size
#
# ValueError: operands could not be broadcast together with shapes (1000,1) (200,1)

# %%
mu = x_test_ans.mean()
mu
# Out:
# 0.004429453935575459

# %%
np.sqrt(mse)

# %%
t0, t1 = 0, 5
b0, b1 = 0.5, 1
k0, k1 = 5, 10
N_grid = 50

B = np.linspace(b0, b1, N_grid)
K = np.linspace(k0, k1, N_grid)

b_grid, k_grid = np.meshgrid(B, K)
b_grid = b_grid.flatten().reshape(-1,1)
k_grid = k_grid.flatten().reshape(-1,1)

t = np.linspace(t0, t1, 50).reshape(1,-1)

#layer_z = []
layer_mean = []
#layer_log_sigma = []

for i in range(3):
  #layer_z.append(np.zeros(N_grid**2))
  layer_mean.append(np.zeros(N_grid**2))
  #layer_log_sigma.append(np.zeros(N_grid**2))

xt_series = generateTrajectory(t, b_grid, k_grid, units=50, samples=N_grid**2)
mean, log_sigma, z = encoder(xt_series)

for i in range(3):
  layer_mean[i] = mean[:,i].numpy().reshape(N_grid, N_grid)

b_grid = b_grid.reshape(N_grid, N_grid)
k_grid = k_grid.reshape(N_grid, N_grid)

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, subplot_kw={'projection': '3d'}, figsize=(18,10))

for i in range(3):
  ax[i].plot_surface(b_grid, k_grid, layer_mean[i])
  ax[i].set_xlabel('b')
  ax[i].set_ylabel('k')
  ax[i].view_init(20,120)
  ax[i].set_zlim3d(-0.20,0.20)

plt.show()

# %% [markdown]
# Below, the model is provided a time series of position as an observation and the position of the pendulum is asked for a range of time to obtain the predicted trajectory of the pendulum.

# %%
#generate observation data and test samples with a fixed value of spring constant and damping parameter
samples = 200
t_obs = np.linspace(0, 5, 50).reshape(1,-1)
t_ques = np.linspace(0, 10, samples).reshape(-1, 1)
#observation data
x_obs = generateTrajectory(t_obs, 0.5, 5, units=50, samples=1)
#test questions as array of times and the corresponding answer as the position of the pendulum
x_true_ans = generateTrajectory(t_ques, 0.5, 5, units=1, samples=samples)

# %%
z_mu = np.zeros(samples*3).reshape(samples, 3)
z_logvar = np.zeros(samples*3).reshape(samples, 3)
z = np.zeros(samples*3).reshape(samples, 3)
#array to store the predicted answers of the model
x_pred_ans = np.zeros(samples).reshape(1,samples)

#generate answer to each questions
z_mu, z_logvar, z, x_pred_ans = pendulum.predict([np.broadcast_to(x_obs, shape=(samples, 50)), t_ques])
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %%
plt.plot(t_ques, x_pred_ans)
plt.plot(t_ques, x_true_ans)
plt.plot()
# Out:
# []

# %%
variational_autoencoder = VAE(encoder, decoder, beta_rec=10., beta_kl=1)
variational_autoencoder.compile(optimizer='adam')
variational_autoencoder.fit(x_train_reshaped, x_train_reshaped, batch_size=128, epochs=10)

# %%
latent_z_mu, latent_z_logvar, x_prediction_reshaped = variational_autoencoder.predict(x_test_reshaped)

# %% [markdown]
# Let us introduce some noise to the images and see how the autoencoder performs on the noised images.

# %%
#create noises for the training and test datasets as random values
train_noise = np.random.uniform(low=-0.7, high=0.7, size=(1, x_train_reshaped.shape[1]))
test_noise = np.random.uniform(low=-0.7, high=0.7, size=(1, x_test_reshaped.shape[1]))

# %%
#add the noise
x_train_noise = x_train_reshaped + train_noise
x_test_noise = x_test_reshaped + test_noise
#clip the noise in the range [0,1]
x_train_noise = np.clip(x_train_noise, a_min=0, a_max=1)
x_test_noise = np.clip(x_test_noise, a_min=0, a_max=1)

# %% [markdown]
# We see that the encoder is performing badly for the noised data. This is because the encoder is not trained to remove the noise. So, lets pass the encoder noised data and train it to produce denoised images.
